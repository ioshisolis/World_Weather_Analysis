# %%
import random
import numpy as np
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hervey bay
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 1 | alofi
# Processing Record 7 of Set 1 | pacific grove
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | changli
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | bharatpur
# Processing Record 12 of Set 1 | the pas
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | roald
# Processing Record 15 of Set 1 | bodrum
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | antalaha
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | fuerte olimpo
# Processing Record 30 of Set 1 | port-gentil
# Processing Record 31 of Set 1 | mankono
# Processing Record 32 of Set 1 | palmer
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | quatre cocos
# Processing Record 37 of Set 1 | souillac
# Processing Record 38 of Set 1 | amga
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | kutum
# Processing Record 42 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 1 | octeville
# Processing Record 44 of Set 1 | camacha
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | tabas
# Processing Record 48 of Set 1 | nalut
# Processing Record 49 of Set 1 | manta
# Processing Record 50 of Set 1 | goderich
# Processing Record 1 of Set 2 | buala
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | barentu
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | harper
# Processing Record 7 of Set 2 | dingle
# Processing Record 8 of Set 2 | isangel
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | outlook
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | ewa beach
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | kunya
# Processing Record 15 of Set 2 | olean
# Processing Record 16 of Set 2 | poum
# Processing Record 17 of Set 2 | hamadan
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | wabana
# Processing Record 21 of Set 2 | monrovia
# Processing Record 22 of Set 2 | san jose
# Processing Record 23 of Set 2 | gushikawa
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | leirvik
# Processing Record 26 of Set 2 | maraba
# Processing Record 27 of Set 2 | bojonegoro
# Processing Record 28 of Set 2 | chipinge
# Processing Record 29 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | lons-le-saunier
# Processing Record 33 of Set 2 | sur
# Processing Record 34 of Set 2 | manavalakurichi
# Processing Record 35 of Set 2 | oktyabrskoye
# Processing Record 36 of Set 2 | medea
# Processing Record 37 of Set 2 | half moon bay
# Processing Record 38 of Set 2 | gamba
# Processing Record 39 of Set 2 | gawler
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | san quintin
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | basco
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | cherrapunji
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | khilok
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | oga
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | fortuna
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | portland
# Processing Record 7 of Set 3 | itaueira
# Processing Record 8 of Set 3 | omboue
# Processing Record 9 of Set 3 | enumclaw
# Processing Record 10 of Set 3 | atar
# Processing Record 11 of Set 3 | maniitsoq
# Processing Record 12 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | hobyo
# Processing Record 15 of Set 3 | praia da vitoria
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | hualmay
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | xichang
# Processing Record 21 of Set 3 | kuytun
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | sitka
# Processing Record 25 of Set 3 | severo-kurilsk
# Processing Record 26 of Set 3 | kalevala
# Processing Record 27 of Set 3 | broome
# Processing Record 28 of Set 3 | cuiluan
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | tarut
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | hoquiam
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | ulladulla
# Processing Record 36 of Set 3 | oldenzaal
# Processing Record 37 of Set 3 | mpulungu
# Processing Record 38 of Set 3 | chaman
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | ostrovnoy
# Processing Record 42 of Set 3 | ullapool
# Processing Record 43 of Set 3 | zelenchukskaya
# Processing Record 44 of Set 3 | obihiro
# Processing Record 45 of Set 3 | birjand
# Processing Record 46 of Set 3 | doka
# Processing Record 47 of Set 3 | olafsvik
# Processing Record 48 of Set 3 | egvekinot
# Processing Record 49 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | artyom
# Processing Record 2 of Set 4 | nanortalik
# Processing Record 3 of Set 4 | ratnagiri
# Processing Record 4 of Set 4 | kapaa
# Processing Record 5 of Set 4 | odweyne
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | laguna
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | westport
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | linda
# Processing Record 14 of Set 4 | sivaki
# Processing Record 15 of Set 4 | deputatskiy
# Processing Record 16 of Set 4 | soyo
# Processing Record 17 of Set 4 | port blair
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | graaff-reinet
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | clyde river
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | tutoia
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | muros
# Processing Record 28 of Set 4 | coruripe
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | ouahigouya
# Processing Record 32 of Set 4 | nanga eboko
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | belyy yar
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | herat
# Processing Record 38 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 4 | santa cruz
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | yulara
# Processing Record 42 of Set 4 | nishihara
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | ulcinj
# Processing Record 45 of Set 4 | port alfred
# Processing Record 46 of Set 4 | severomuysk
# Processing Record 47 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 4 | contramaestre
# Processing Record 49 of Set 4 | saint-augustin
# Processing Record 50 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 1 of Set 5 | mayor pablo lagerenza
# Processing Record 2 of Set 5 | uruzgan
# Processing Record 3 of Set 5 | sept-iles
# Processing Record 4 of Set 5 | poco branco
# Processing Record 5 of Set 5 | alta floresta
# Processing Record 6 of Set 5 | turayf
# Processing Record 7 of Set 5 | puerto quijarro
# Processing Record 8 of Set 5 | bud
# Processing Record 9 of Set 5 | alice springs
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | iquique
# Processing Record 12 of Set 5 | sunndalsora
# Processing Record 13 of Set 5 | hendek
# Processing Record 14 of Set 5 | springbok
# Processing Record 15 of Set 5 | termiz
# Processing Record 16 of Set 5 | victor harbor
# Processing Record 17 of Set 5 | bull savanna
# Processing Record 18 of Set 5 | kargasok
# Processing Record 19 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 5 | necochea
# Processing Record 21 of Set 5 | fort frances
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | turan
# Processing Record 24 of Set 5 | algiers
# Processing Record 25 of Set 5 | terekli-mekteb
# Processing Record 26 of Set 5 | port hardy
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | dwarka
# Processing Record 29 of Set 5 | russell
# Processing Record 30 of Set 5 | puertollano
# Processing Record 31 of Set 5 | niamey
# Processing Record 32 of Set 5 | poim
# Processing Record 33 of Set 5 | atambua
# Processing Record 34 of Set 5 | leh
# Processing Record 35 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 5 | evensk
# Processing Record 37 of Set 5 | leticia
# Processing Record 38 of Set 5 | bushenyi
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | kulu
# Processing Record 41 of Set 5 | sobolevo
# Processing Record 42 of Set 5 | kempsey
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | henties bay
# Processing Record 45 of Set 5 | duku
# Processing Record 46 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 5 | baruun-urt
# Processing Record 48 of Set 5 | kerman
# Processing Record 49 of Set 5 | gornopravdinsk
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | visby
# Processing Record 2 of Set 6 | aklavik
# Processing Record 3 of Set 6 | borama
# City not found. Skipping...
# Processing Record 4 of Set 6 | griffith
# Processing Record 5 of Set 6 | ouadda
# Processing Record 6 of Set 6 | hare bay
# Processing Record 7 of Set 6 | general roca
# Processing Record 8 of Set 6 | ibra
# Processing Record 9 of Set 6 | bonthe
# Processing Record 10 of Set 6 | ugoofaaru
# Processing Record 11 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | tautira
# Processing Record 13 of Set 6 | prainha
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | moses lake
# Processing Record 17 of Set 6 | ihosy
# Processing Record 18 of Set 6 | wanning
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | huilong
# Processing Record 22 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 6 | sao joao da barra
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | pochutla
# Processing Record 26 of Set 6 | saint austell
# Processing Record 27 of Set 6 | hun
# Processing Record 28 of Set 6 | huarmey
# Processing Record 29 of Set 6 | coahuayana
# Processing Record 30 of Set 6 | hofn
# Processing Record 31 of Set 6 | gobabis
# Processing Record 32 of Set 6 | trairi
# Processing Record 33 of Set 6 | wenling
# Processing Record 34 of Set 6 | denpasar
# Processing Record 35 of Set 6 | nanning
# Processing Record 36 of Set 6 | pangkalanbuun
# Processing Record 37 of Set 6 | hambantota
# Processing Record 38 of Set 6 | igarka
# Processing Record 39 of Set 6 | tura
# Processing Record 40 of Set 6 | rogun
# City not found. Skipping...
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | boa vista
# Processing Record 43 of Set 6 | saint-pierre
# Processing Record 44 of Set 6 | villazon
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | sao filipe
# Processing Record 47 of Set 6 | jalu
# Processing Record 48 of Set 6 | kaitangata
# Processing Record 49 of Set 6 | wenzhou
# Processing Record 50 of Set 6 | batemans bay
# Processing Record 1 of Set 7 | lakes entrance
# Processing Record 2 of Set 7 | choucheng
# City not found. Skipping...
# Processing Record 3 of Set 7 | ubaque
# Processing Record 4 of Set 7 | bera
# Processing Record 5 of Set 7 | bom jesus
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 7 | zamosc
# Processing Record 9 of Set 7 | escarcega
# Processing Record 10 of Set 7 | teguldet
# Processing Record 11 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 7 | aksu
# Processing Record 13 of Set 7 | rio gallegos
# Processing Record 14 of Set 7 | sao gabriel da cachoeira
# Processing Record 15 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 16 of Set 7 | praia
# Processing Record 17 of Set 7 | ikom
# Processing Record 18 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 7 | danane
# Processing Record 20 of Set 7 | rach gia
# Processing Record 21 of Set 7 | marataizes
# Processing Record 22 of Set 7 | vostok
# Processing Record 23 of Set 7 | pitkyaranta
# Processing Record 24 of Set 7 | nizwa
# Processing Record 25 of Set 7 | minapan
# Processing Record 26 of Set 7 | byron bay
# Processing Record 27 of Set 7 | jasper
# Processing Record 28 of Set 7 | puerto del rosario
# Processing Record 29 of Set 7 | erzin
# Processing Record 30 of Set 7 | shimoda
# Processing Record 31 of Set 7 | izumo
# Processing Record 32 of Set 7 | douglas
# Processing Record 33 of Set 7 | kostino
# Processing Record 34 of Set 7 | gizo
# Processing Record 35 of Set 7 | bowen
# Processing Record 36 of Set 7 | the valley
# Processing Record 37 of Set 7 | komsomolskiy
# Processing Record 38 of Set 7 | lively
# Processing Record 39 of Set 7 | makakilo city
# Processing Record 40 of Set 7 | gat
# Processing Record 41 of Set 7 | mocuba
# Processing Record 42 of Set 7 | batagay-alyta
# Processing Record 43 of Set 7 | lorengau
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | fairbanks
# Processing Record 46 of Set 7 | grindavik
# Processing Record 47 of Set 7 | ngunguru
# Processing Record 48 of Set 7 | longyearbyen
# Processing Record 49 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 7 | luanda
# Processing Record 1 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 8 | mount pleasant
# Processing Record 3 of Set 8 | altay
# Processing Record 4 of Set 8 | moctezuma
# Processing Record 5 of Set 8 | mount gambier
# Processing Record 6 of Set 8 | tiznit
# Processing Record 7 of Set 8 | norman wells
# Processing Record 8 of Set 8 | chandur bazar
# Processing Record 9 of Set 8 | aban
# Processing Record 10 of Set 8 | aloleng
# Processing Record 11 of Set 8 | changping
# Processing Record 12 of Set 8 | coari
# Processing Record 13 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 8 | hamilton
# Processing Record 15 of Set 8 | puyang
# Processing Record 16 of Set 8 | sabha
# Processing Record 17 of Set 8 | san cristobal
# Processing Record 18 of Set 8 | mwinilunga
# Processing Record 19 of Set 8 | boyolangu
# Processing Record 20 of Set 8 | mao
# Processing Record 21 of Set 8 | duayaw nkwanta
# Processing Record 22 of Set 8 | sam phran
# Processing Record 23 of Set 8 | dicabisagan
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | ojinaga
# Processing Record 26 of Set 8 | narayangarh
# Processing Record 27 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 8 | mount darwin
# Processing Record 29 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 8 | guerrero negro
# Processing Record 31 of Set 8 | channel-port aux basques
# Processing Record 32 of Set 8 | semnan
# Processing Record 33 of Set 8 | mnogovershinnyy
# Processing Record 34 of Set 8 | biltine
# Processing Record 35 of Set 8 | comodoro rivadavia
# Processing Record 36 of Set 8 | chicama
# Processing Record 37 of Set 8 | hovd
# Processing Record 38 of Set 8 | santa isabel do rio negro
# Processing Record 39 of Set 8 | consuegra
# Processing Record 40 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 8 | waycross
# Processing Record 42 of Set 8 | sola
# Processing Record 43 of Set 8 | umm lajj
# Processing Record 44 of Set 8 | xihe
# Processing Record 45 of Set 8 | auki
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | bagra
# Processing Record 48 of Set 8 | yuci
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | broken hill
# Processing Record 1 of Set 9 | akureyri
# Processing Record 2 of Set 9 | laborie
# Processing Record 3 of Set 9 | camana
# Processing Record 4 of Set 9 | sibanicu
# Processing Record 5 of Set 9 | camocim
# Processing Record 6 of Set 9 | tahoua
# Processing Record 7 of Set 9 | leopold
# Processing Record 8 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 9 | tuskegee
# Processing Record 11 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 9 | anadyr
# Processing Record 13 of Set 9 | pisco
# Processing Record 14 of Set 9 | agadir
# Processing Record 15 of Set 9 | pahrump
# Processing Record 16 of Set 9 | panaba
# Processing Record 17 of Set 9 | dalvik
# Processing Record 18 of Set 9 | kalabo
# Processing Record 19 of Set 9 | corinto
# Processing Record 20 of Set 9 | topolcani
# Processing Record 21 of Set 9 | flin flon
# Processing Record 22 of Set 9 | omsukchan
# Processing Record 23 of Set 9 | san patricio
# Processing Record 24 of Set 9 | celestun
# Processing Record 25 of Set 9 | asahikawa
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | kununurra
# Processing Record 28 of Set 9 | kadiri
# Processing Record 29 of Set 9 | le port
# Processing Record 30 of Set 9 | lavrentiya
# Processing Record 31 of Set 9 | meiktila
# Processing Record 32 of Set 9 | grand-santi
# Processing Record 33 of Set 9 | xining
# Processing Record 34 of Set 9 | charters towers
# Processing Record 35 of Set 9 | riyadh
# Processing Record 36 of Set 9 | husavik
# Processing Record 37 of Set 9 | south venice
# Processing Record 38 of Set 9 | vadso
# Processing Record 39 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 40 of Set 9 | nuuk
# Processing Record 41 of Set 9 | paamiut
# Processing Record 42 of Set 9 | olinda
# Processing Record 43 of Set 9 | luohe
# Processing Record 44 of Set 9 | oranjemund
# Processing Record 45 of Set 9 | smithers
# Processing Record 46 of Set 9 | saint augustine
# Processing Record 47 of Set 9 | garowe
# Processing Record 48 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 9 | sinobong
# City not found. Skipping...
# Processing Record 50 of Set 9 | kidal
# Processing Record 1 of Set 10 | ejido
# Processing Record 2 of Set 10 | cherskiy
# Processing Record 3 of Set 10 | christchurch
# Processing Record 4 of Set 10 | boromo
# Processing Record 5 of Set 10 | tracy
# Processing Record 6 of Set 10 | owando
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | chapais
# Processing Record 9 of Set 10 | namibe
# Processing Record 10 of Set 10 | shieli
# Processing Record 11 of Set 10 | jega
# Processing Record 12 of Set 10 | palu
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | kusk
# City not found. Skipping...
# Processing Record 15 of Set 10 | rypefjord
# Processing Record 16 of Set 10 | calama
# Processing Record 17 of Set 10 | jiangdu
# Processing Record 18 of Set 10 | jalingo
# Processing Record 19 of Set 10 | vanimo
# Processing Record 20 of Set 10 | australind
# Processing Record 21 of Set 10 | pemberton
# Processing Record 22 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 23 of Set 10 | plouzane
# Processing Record 24 of Set 10 | brownwood
# Processing Record 25 of Set 10 | casas grandes
# Processing Record 26 of Set 10 | ambovombe
# Processing Record 27 of Set 10 | anchorage
# Processing Record 28 of Set 10 | duz
# City not found. Skipping...
# Processing Record 29 of Set 10 | timmins
# Processing Record 30 of Set 10 | penzance
# Processing Record 31 of Set 10 | chumikan
# Processing Record 32 of Set 10 | galveston
# Processing Record 33 of Set 10 | qaqortoq
# Processing Record 34 of Set 10 | qarqin
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | san pedro
# Processing Record 37 of Set 10 | mahibadhoo
# Processing Record 38 of Set 10 | kalmunai
# Processing Record 39 of Set 10 | talcahuano
# Processing Record 40 of Set 10 | haines junction
# Processing Record 41 of Set 10 | lazaro cardenas
# Processing Record 42 of Set 10 | kieta
# Processing Record 43 of Set 10 | ostersund
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | bubaque
# Processing Record 46 of Set 10 | bairiki
# Processing Record 47 of Set 10 | shymkent
# Processing Record 48 of Set 10 | meulaboh
# Processing Record 49 of Set 10 | polson
# Processing Record 50 of Set 10 | gillette
# Processing Record 1 of Set 11 | chirilagua
# Processing Record 2 of Set 11 | koyelga
# Processing Record 3 of Set 11 | kindu
# Processing Record 4 of Set 11 | nata
# Processing Record 5 of Set 11 | otteveny
# Processing Record 6 of Set 11 | klaksvik
# Processing Record 7 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 9 of Set 11 | vila
# Processing Record 10 of Set 11 | luderitz
# Processing Record 11 of Set 11 | buncrana
# Processing Record 12 of Set 11 | punta umbria
# Processing Record 13 of Set 11 | toropets
# Processing Record 14 of Set 11 | bushehr
# Processing Record 15 of Set 11 | rzhev
# Processing Record 16 of Set 11 | nampula
# Processing Record 17 of Set 11 | hasaki
# Processing Record 18 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 11 | lubango
# Processing Record 20 of Set 11 | ullal
# Processing Record 21 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 22 of Set 11 | port said
# Processing Record 23 of Set 11 | marondera
# Processing Record 24 of Set 11 | mirnyy
# Processing Record 25 of Set 11 | bambous virieux
# Processing Record 26 of Set 11 | urumqi
# Processing Record 27 of Set 11 | manokwari
# Processing Record 28 of Set 11 | bani
# Processing Record 29 of Set 11 | iqaluit
# Processing Record 30 of Set 11 | den helder
# Processing Record 31 of Set 11 | touros
# Processing Record 32 of Set 11 | yerbogachen
# Processing Record 33 of Set 11 | lasa
# Processing Record 34 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 11 | sechura
# Processing Record 36 of Set 11 | nome
# Processing Record 37 of Set 11 | zapolyarnyy
# Processing Record 38 of Set 11 | axim
# Processing Record 39 of Set 11 | plainfield
# Processing Record 40 of Set 11 | sao jose da coroa grande
# Processing Record 41 of Set 11 | chakrata
# Processing Record 42 of Set 11 | khasan
# Processing Record 43 of Set 11 | jerez
# Processing Record 44 of Set 11 | bakurianis andeziti
# Processing Record 45 of Set 11 | stephenville
# Processing Record 46 of Set 11 | frolovo
# Processing Record 47 of Set 11 | port augusta
# Processing Record 48 of Set 11 | constitucion
# Processing Record 49 of Set 11 | winsum
# Processing Record 50 of Set 11 | zhigansk
# Processing Record 1 of Set 12 | inhambane
# Processing Record 2 of Set 12 | zhoucheng
# Processing Record 3 of Set 12 | brae
# Processing Record 4 of Set 12 | puerto carreno
# Processing Record 5 of Set 12 | yumen
# Processing Record 6 of Set 12 | ozernovskiy
# Processing Record 7 of Set 12 | tsybli
# Processing Record 8 of Set 12 | kaabong
# Processing Record 9 of Set 12 | richards bay
# Processing Record 10 of Set 12 | gaoua
# Processing Record 11 of Set 12 | anloga
# Processing Record 12 of Set 12 | nyuksenitsa
# Processing Record 13 of Set 12 | soligalich
# Processing Record 14 of Set 12 | chakia
# Processing Record 15 of Set 12 | akyab
# Processing Record 16 of Set 12 | loikaw
# Processing Record 17 of Set 12 | ambilobe
# Processing Record 18 of Set 12 | gimli
# Processing Record 19 of Set 12 | san policarpo
# Processing Record 20 of Set 12 | manchester
# Processing Record 21 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 12 | majalgaon
# Processing Record 23 of Set 12 | port macquarie
# Processing Record 24 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | botucatu
# Processing Record 27 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 28 of Set 12 | kudahuvadhoo
# Processing Record 29 of Set 12 | mozdok
# Processing Record 30 of Set 12 | starkville
# Processing Record 31 of Set 12 | vredendal
# Processing Record 32 of Set 12 | port antonio
# Processing Record 33 of Set 12 | kautokeino
# Processing Record 34 of Set 12 | pak phanang
# Processing Record 35 of Set 12 | kendari
# Processing Record 36 of Set 12 | mecca
# Processing Record 37 of Set 12 | san mateo del mar
# Processing Record 38 of Set 12 | bilibino
# Processing Record 39 of Set 12 | baturaja
# Processing Record 40 of Set 12 | alamosa
# Processing Record 41 of Set 12 | santa elena
# Processing Record 42 of Set 12 | khalkhal
# Processing Record 43 of Set 12 | santa rosa
# Processing Record 44 of Set 12 | padang
# Processing Record 45 of Set 12 | mongo
# Processing Record 46 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 12 | xiaoyi
# Processing Record 48 of Set 12 | saint-francois
# Processing Record 49 of Set 12 | katsuura
# Processing Record 50 of Set 12 | ndele
# Processing Record 1 of Set 13 | eyl
# Processing Record 2 of Set 13 | ust-tsilma
# Processing Record 3 of Set 13 | joshimath
# Processing Record 4 of Set 13 | mendeleyevsk
# Processing Record 5 of Set 13 | myanaung
# Processing Record 6 of Set 13 | sao miguel do araguaia
# Processing Record 7 of Set 13 | blackwater
# Processing Record 8 of Set 13 | zalukokoazhe
# Processing Record 9 of Set 13 | tigil
# Processing Record 10 of Set 13 | nara
# Processing Record 11 of Set 13 | saldanha
# Processing Record 12 of Set 13 | mayo
# Processing Record 13 of Set 13 | grandview
# Processing Record 14 of Set 13 | balaka
# Processing Record 15 of Set 13 | amot
# Processing Record 16 of Set 13 | vestmannaeyjar
# Processing Record 17 of Set 13 | mombasa
# Processing Record 18 of Set 13 | hami
# Processing Record 19 of Set 13 | yeppoon
# Processing Record 20 of Set 13 | mackay
# Processing Record 21 of Set 13 | labytnangi
# Processing Record 22 of Set 13 | port hedland
# Processing Record 23 of Set 13 | huangmei
# Processing Record 24 of Set 13 | los llanos de aridane
# Processing Record 25 of Set 13 | dunedin
# Processing Record 26 of Set 13 | margate
# Processing Record 27 of Set 13 | golynki
# Processing Record 28 of Set 13 | tuatapere
# Processing Record 29 of Set 13 | yelizovo
# Processing Record 30 of Set 13 | jumla
# Processing Record 31 of Set 13 | nelson bay
# Processing Record 32 of Set 13 | tuy hoa
# Processing Record 33 of Set 13 | nizhniy odes
# Processing Record 34 of Set 13 | njombe
# Processing Record 35 of Set 13 | baykit
# Processing Record 36 of Set 13 | storforshei
# Processing Record 37 of Set 13 | pedernales
# Processing Record 38 of Set 13 | tveit
# Processing Record 39 of Set 13 | prince rupert
# Processing Record 40 of Set 13 | marawi
# Processing Record 41 of Set 13 | ust-omchug
# Processing Record 42 of Set 13 | tirat karmel
# Processing Record 43 of Set 13 | koryukivka
# Processing Record 44 of Set 13 | saint-louis
# Processing Record 45 of Set 13 | katete
# Processing Record 46 of Set 13 | port lincoln
# Processing Record 47 of Set 13 | cangzhou
# Processing Record 48 of Set 13 | valparaiso
# Processing Record 49 of Set 13 | mogwase
# Processing Record 50 of Set 13 | thinadhoo
# Processing Record 1 of Set 14 | kostomuksha
# Processing Record 2 of Set 14 | raudeberg
# Processing Record 3 of Set 14 | taber
# Processing Record 4 of Set 14 | taoudenni
# Processing Record 5 of Set 14 | svetlyy
# Processing Record 6 of Set 14 | luganville
# Processing Record 7 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 14 | narsaq
# Processing Record 9 of Set 14 | amarante do maranhao
# Processing Record 10 of Set 14 | alyangula
# Processing Record 11 of Set 14 | sungairaya
# Processing Record 12 of Set 14 | lata
# Processing Record 13 of Set 14 | kupang
# Processing Record 14 of Set 14 | korsakov
# Processing Record 15 of Set 14 | puerto leguizamo
# Processing Record 16 of Set 14 | sisimiut
# Processing Record 17 of Set 14 | sioux lookout
# Processing Record 18 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 14 | licheng
# Processing Record 20 of Set 14 | songjianghe
# Processing Record 21 of Set 14 | arroyos y esteros
# Processing Record 22 of Set 14 | taylor
# Processing Record 23 of Set 14 | lev tolstoy
# Processing Record 24 of Set 14 | lagoa
# Processing Record 25 of Set 14 | hauzenberg
# Processing Record 26 of Set 14 | concarneau
# Processing Record 27 of Set 14 | krasnoselkup
# Processing Record 28 of Set 14 | clarksville
# Processing Record 29 of Set 14 | west wendover
# Processing Record 30 of Set 14 | turukhansk
# Processing Record 31 of Set 14 | grand gaube
# Processing Record 32 of Set 14 | batticaloa
# Processing Record 33 of Set 14 | college
# Processing Record 34 of Set 14 | flinders
# Processing Record 35 of Set 14 | esperance
# Processing Record 36 of Set 14 | ust-kan
# Processing Record 37 of Set 14 | kedrovyy
# Processing Record 38 of Set 14 | matamoros
# Processing Record 39 of Set 14 | kastamonu
# Processing Record 40 of Set 14 | pandan
# Processing Record 41 of Set 14 | mastic beach
# Processing Record 42 of Set 14 | barra patuca
# Processing Record 43 of Set 14 | puerto narino
# Processing Record 44 of Set 14 | contai
# Processing Record 45 of Set 14 | mont-de-marsan
# Processing Record 46 of Set 14 | bandarbeyla
# Processing Record 47 of Set 14 | wilmington island
# Processing Record 48 of Set 14 | launceston
# Processing Record 49 of Set 14 | tibati
# Processing Record 50 of Set 14 | bjornevatn
# Processing Record 1 of Set 15 | saint-joseph
# Processing Record 2 of Set 15 | bulgan
# Processing Record 3 of Set 15 | toyo
# Processing Record 4 of Set 15 | chapleau
# Processing Record 5 of Set 15 | sao felix do xingu
# Processing Record 6 of Set 15 | la ronge
# Processing Record 7 of Set 15 | kikwit
# Processing Record 8 of Set 15 | lompoc
# Processing Record 9 of Set 15 | dzhebariki-khaya
# Processing Record 10 of Set 15 | ponta delgada
# Processing Record 11 of Set 15 | corvallis
# Processing Record 12 of Set 15 | matagami
# Processing Record 13 of Set 15 | kiunga
# Processing Record 14 of Set 15 | toccoa
# Processing Record 15 of Set 15 | enshi
# Processing Record 16 of Set 15 | seoul
# Processing Record 17 of Set 15 | san carlos
# Processing Record 18 of Set 15 | bima
# Processing Record 19 of Set 15 | miraflores
# Processing Record 20 of Set 15 | nemuro
# Processing Record 21 of Set 15 | lethbridge
# Processing Record 22 of Set 15 | korgen
# Processing Record 23 of Set 15 | hashtrud
# Processing Record 24 of Set 15 | okha
# Processing Record 25 of Set 15 | katra
# Processing Record 26 of Set 15 | hay river
# Processing Record 27 of Set 15 | siquirres
# Processing Record 28 of Set 15 | moose factory
# Processing Record 29 of Set 15 | thunder bay
# Processing Record 30 of Set 15 | zheshart
# Processing Record 31 of Set 15 | pueblo
# Processing Record 32 of Set 15 | waw
# Processing Record 33 of Set 15 | asau
# Processing Record 34 of Set 15 | puerto escondido
# Processing Record 35 of Set 15 | ayagoz
# Processing Record 36 of Set 15 | nyaunglebin
# Processing Record 37 of Set 15 | maldonado
# Processing Record 38 of Set 15 | pozo colorado
# Processing Record 39 of Set 15 | vila velha
# Processing Record 40 of Set 15 | ikalamavony
# Processing Record 41 of Set 15 | neuquen
# Processing Record 42 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 15 | campos novos
# Processing Record 44 of Set 15 | yangambi
# Processing Record 45 of Set 15 | chiredzi
# Processing Record 46 of Set 15 | mporokoso
# Processing Record 47 of Set 15 | falmouth
# Processing Record 48 of Set 15 | vakhrushev
# Processing Record 49 of Set 15 | ust-kuyga
# Processing Record 50 of Set 15 | kolyshley
# Processing Record 1 of Set 16 | stornoway
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hervey Bay      AU -25.2986  152.8535     75.31        50          29
# 1       Bengkulu      ID  -3.8004  102.2655     76.05        88          99
# 2         Dikson      RU  73.5069   80.5464     19.31        89          85
# 3         Faanui      PF -16.4833 -151.7500     78.75        76          20
# 4          Alofi      NU -19.0595 -169.9187     82.29        74          75
# 5  Pacific Grove      US  36.6177 -121.9166     75.97        81           1
# 6         Bethel      US  41.3712  -73.4140     45.48        73           1
# 7        Changli      CN  39.7042  119.1506     51.46        75           0
# 8         Castro      BR -24.7911  -50.0119     65.77        75          73
# 9      Bharatpur      IN  27.2167   77.4833     68.27        46           0
#
#    Wind Speed Current Description
# 0        8.72    scattered clouds
# 1        3.44     overcast clouds
# 2       12.21     overcast clouds
# 3        3.20          few clouds
# 4       12.66       broken clouds
# 5        1.99                 fog
# 6        3.44           clear sky
# 7        1.92           clear sky
# 8        2.06       broken clouds
# 9        6.11           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-85c3a7d8006d> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
